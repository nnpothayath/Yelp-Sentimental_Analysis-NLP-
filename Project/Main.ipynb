# %%
#Importing the package that helps in importing other jupyter notebooks
import nbimporter

#Importing the other jupyter notebooks
import PythonWidget
# Out:
# Importing Jupyter notebook from PythonWidget.ipynb
# Importing Jupyter notebook from DataOperations.ipynb
# Importing Jupyter notebook from OperationsOnText.ipynb
# Importing Jupyter notebook from WordCloud.ipynb
# Importing Jupyter notebook from MachineLearningProblem.ipynb

# %%
PythonWidget.start()
# Out:
# You have selected Business 1
# Gathering Raw Data
# Gathered the Raw Data
# Getting the Raw Text and the rating corresponding to the texts
# Obtained the raw text and ratings
# Average Rating for your business is 3.87437879625
# The minimum rating obtained for your business is 1
# The maximum rating obtained for your business is 5
# Preparing to clean reviews
# Cleaned all reviews
# +-------+-------+
# |  Word | Count |
# +-------+-------+
# |  room |  5680 |
# | hotel |  5096 |
# |  one  |  2400 |
# |  stay |  2196 |
# | great |  2164 |
# |  get  |  2015 |
# | place |  1965 |
# |  like |  1933 |
# | rooms |  1742 |
# |  time |  1737 |
# +-------+-------+
# Percentage of positive reviews = 90.9718387631143
# Percentage of negative reviews = 8.337934842628382
# Generating a word cloud for all the reviews
# Generating the positive words' word cloud

# %%
PythonWidget.MLProblem()
# Out:
# You have selected to build a user-specific model for Kevin
# Gathering Raw Data
# Gathered the Raw Data
# Preparing to clean reviews
# Cleaned all reviews
# Preparing to vectorize the text using tf-idf
# Completed tf-idf vectorization of text data
# Running Gaussian Naive Bayes
# Accuracy: 0.46 (+/- 0.07)
# Running Linear SVM Classifier
# Accuracy: 0.50 (+/- 0.04)
# Running Random Forest Classifier
# Accuracy: 0.46 (+/- 0.04)
# Obtaining best hyper-parameters for Linear SVM Classifier
# {'C': 0.5, 'class_weight': None, 'loss': 'squared_hinge'}
# 0.5
# Accuracy: 0.45 (+/- 0.02)
